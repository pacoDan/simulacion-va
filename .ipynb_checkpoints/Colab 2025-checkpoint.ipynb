# %% [markdown]
# # 1. Carga de bibliotetas
#
# Seccion para instalar e importar bibliotecas necesarias

# %%
# Acá instalamos la biblioteca fitter para el ajuste de funciones
pip install fitter
# Out:
# Collecting fitter
#   Downloading fitter-1.7.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /usr/local/lib/python3.10/dist-packages (from fitter) (8.1.7)
# Requirement already satisfied: joblib<2.0.0,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.4.2)
# Collecting loguru<0.8.0,>=0.7.2 (from fitter)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Collecting matplotlib<4.0.0,>=3.7.2 (from fitter)
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from fitter) (2.2.2)
# Collecting rich-click<2.0.0,>=1.7.2 (from fitter)
#   Downloading rich_click-1.8.3-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: scipy<2.0.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.13.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2024.2)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (13.9.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.2->fitter) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (0.1.2)
# Downloading fitter-1.7.1-py3-none-any.whl (26 kB)
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.6 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 71.8 MB/s eta 0:00:00
# Downloading rich_click-1.8.3-py3-none-any.whl (35 kB)
# Installing collected packages: loguru, matplotlib, rich-click, fitter
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed fitter-1.7.1 loguru-0.7.2 matplotlib-3.9.2 rich-click-1.8.3

# %%
# Acá importarmos todas las bibliotecas necesarias: Pandas, Numpy, Scipy y Fitter
from fitter import Fitter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Esto se hace para montar el gogle drive y poder acceder datos alojados allí.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2. Carga de datos
#
# Utilizaremos los datos de recorrido de bicicletas públicas de la ciudad de Buenos Aires
# https://data.buenosaires.gob.ar/dataset/bicicletas-publicas
#
# Bajaremos el archivo "Recorridos Realizados 2023 (ZIP)", descomprimiremos el archivo csv presente ("trips_2023.csv")y lo alojamos dentro de la carpeta "Colab Notebooks" de nuestro Google Drive

# %%
# En esta parte del código se debe modificar la ubicación correcta del google drive
bicis = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/EPIO/Datos/trips_2023.csv')

# %% [markdown]
# # 3. Análisis Exploratorio de Datos

# %%
# Corroboramos que el tipo de dato de la variable "bicis" es un dataframe
type(bicis)
# Out:
# pandas.core.frame.DataFrame

# %%
# Primeras lineas de nuestro dataframe
bicis.head()
# Out:
#    Unnamed: 0       Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0           1  17910696BAEcobici              1,848    2023-04-24 10:30:10
# 1           2  17600256BAEcobici                288    2023-03-22 17:40:55
# 2           3  17255670BAEcobici              1,103    2023-02-15 23:12:22
# 3           4  17996972BAEcobici              1,165    2023-05-03 11:00:20
# 4           5  17148836BAEcobici                378    2023-02-06 06:50:58
#
#   id_estacion_origen        nombre_estacion_origen  \
# 0       358BAEcobici                  249 - Balbín
# 1       444BAEcobici  061 - Ministerio de Economia
# 2       280BAEcobici           222 - SIMON BOLIVAR
# 3       273BAEcobici                  223 - GAINZA
# 4        65BAEcobici          065 - Julián Álvarez
#
#            direccion_estacion_origen  long_estacion_origen  \
# 0                        2519 Conesa            -58.465586
# 1  Balcarce e Yrigoyen, Hipolito Av.            -58.370716
# 2   1701 Fernandez Moreno, Baldomero            -58.449379
# 3       494 Gainza, Martin De, Gral.            -58.446751
# 4                        3822 Guemes            -58.415787
#
#    lat_estacion_origen fecha_destino_recorrido id_estacion_destino  \
# 0           -34.561486     2023-04-24 11:00:58        278BAEcobici
# 1           -34.608936     2023-03-22 17:45:43          3BAEcobici
# 2           -34.633528     2023-02-15 23:30:45        280BAEcobici
# 3           -34.616758     2023-05-03 11:19:45        367BAEcobici
# 4           -34.587312     2023-02-06 06:57:16         14BAEcobici
#
#   nombre_estacion_destino         direccion_estacion_destino  \
# 0            233 - MONROE                        2519 Superi
# 1            003 - ADUANA                  Moreno & Azopardo
# 2     222 - SIMON BOLIVAR   1701 Fernandez Moreno, Baldomero
# 3       287 - Belaustegui        Belaustegui, Luis, Dr. 2890
# 4          014 - Pacifico  Santa Fe Av. & Bullrich, Int. Av.
#
#    long_estacion_destino  lat_estacion_destino       id_usuario  \
# 0             -58.469813            -34.564122  861866BAEcobici
# 1             -58.368174            -34.611102  217525BAEcobici
# 2             -58.449379            -34.633528  954201BAEcobici
# 3             -58.477209            -34.616212  179414BAEcobici
# 4             -58.426387            -34.577424    8098BAEcobici
#
#   modelo_bicicleta  género
# 0           ICONIC    MALE
# 1           ICONIC  FEMALE
# 2           ICONIC    MALE
# 3           ICONIC    MALE
# 4           ICONIC    MALE

# %%
# Si solo quiero los nombres de las columnas en formato lista
bicis.columns
# Out:
# Index(['Unnamed: 0', 'Id_recorrido', 'duracion_recorrido',
#        'fecha_origen_recorrido', 'id_estacion_origen',
#        'nombre_estacion_origen', 'direccion_estacion_origen',
#        'long_estacion_origen', 'lat_estacion_origen',
#        'fecha_destino_recorrido', 'id_estacion_destino',
#        'nombre_estacion_destino', 'direccion_estacion_destino',
#        'long_estacion_destino', 'lat_estacion_destino', 'id_usuario',
#        'modelo_bicicleta', 'género'],
#       dtype='object')

# %%
# Dimensionalidad del dataframe
bicis.shape
# Out:
# (2622331, 18)

# %%
# El tipo de dato de cada una de las columnas
# Acá veo que 'duracion_recorrido', 'fecha_origen_recorrido' y 'fecha_destino_recorrido'
# son de tipo object (texto) y no está bueno eso
bicis.dtypes
# Out:
# Unnamed: 0                      int64
# Id_recorrido                   object
# duracion_recorrido             object
# fecha_origen_recorrido         object
# id_estacion_origen             object
# nombre_estacion_origen         object
# direccion_estacion_origen      object
# long_estacion_origen          float64
# lat_estacion_origen           float64
# fecha_destino_recorrido        object
# id_estacion_destino            object
# nombre_estacion_destino        object
# direccion_estacion_destino     object
# long_estacion_destino         float64
# lat_estacion_destino          float64
# id_usuario                     object
# modelo_bicicleta               object
# género                         object
# dtype: object

# %%
# Para acceder a una columna específica puedo usar el operador punto:
bicis.nombre_estacion_origen
# Out:
# 0                          249 - Balbín
# 1          061 - Ministerio de Economia
# 2                   222 - SIMON BOLIVAR
# 3                          223 - GAINZA
# 4                  065 - Julián Álvarez
#                        ...
# 2622326                  014 - Pacifico
# 2622327          368 - PLAZA DE LA SHOÁ
# 2622328          261 - QUINTEROS LIDORO
# 2622329               338 - AV. CABILDO
# 2622330            317 - ESCUELA RAGGIO
# Name: nombre_estacion_origen, Length: 2622331, dtype: object

# %%
# O el operador corchete:
bicis['nombre_estacion_origen']

# %% [markdown]
# # 4. Preparación de Datos
#
# Si debo modificar una columna, es conveniente crear una nueva y no pisar la original. Lo mismo para los dataframes

# %%
# Creo dos nuevas columnas con las fechas con el tipo de dato correcto.
bicis['fecha_origen_recorrido_dt'] = pd.to_datetime(bicis['fecha_origen_recorrido'])
bicis['fecha_destino_recorrido_dt'] = pd.to_datetime(bicis['fecha_destino_recorrido'])

# %%
bicis.head()
# Out:
#    Unnamed: 0       Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0           1  17910696BAEcobici              1,848    2023-04-24 10:30:10
# 1           2  17600256BAEcobici                288    2023-03-22 17:40:55
# 2           3  17255670BAEcobici              1,103    2023-02-15 23:12:22
# 3           4  17996972BAEcobici              1,165    2023-05-03 11:00:20
# 4           5  17148836BAEcobici                378    2023-02-06 06:50:58
#
#   id_estacion_origen        nombre_estacion_origen  \
# 0       358BAEcobici                  249 - Balbín
# 1       444BAEcobici  061 - Ministerio de Economia
# 2       280BAEcobici           222 - SIMON BOLIVAR
# 3       273BAEcobici                  223 - GAINZA
# 4        65BAEcobici          065 - Julián Álvarez
#
#            direccion_estacion_origen  long_estacion_origen  \
# 0                        2519 Conesa            -58.465586
# 1  Balcarce e Yrigoyen, Hipolito Av.            -58.370716
# 2   1701 Fernandez Moreno, Baldomero            -58.449379
# 3       494 Gainza, Martin De, Gral.            -58.446751
# 4                        3822 Guemes            -58.415787
#
#    lat_estacion_origen fecha_destino_recorrido id_estacion_destino  \
# 0           -34.561486     2023-04-24 11:00:58        278BAEcobici
# 1           -34.608936     2023-03-22 17:45:43          3BAEcobici
# 2           -34.633528     2023-02-15 23:30:45        280BAEcobici
# 3           -34.616758     2023-05-03 11:19:45        367BAEcobici
# 4           -34.587312     2023-02-06 06:57:16         14BAEcobici
#
#   nombre_estacion_destino         direccion_estacion_destino  \
# 0            233 - MONROE                        2519 Superi
# 1            003 - ADUANA                  Moreno & Azopardo
# 2     222 - SIMON BOLIVAR   1701 Fernandez Moreno, Baldomero
# 3       287 - Belaustegui        Belaustegui, Luis, Dr. 2890
# 4          014 - Pacifico  Santa Fe Av. & Bullrich, Int. Av.
#
#    long_estacion_destino  lat_estacion_destino       id_usuario  \
# 0             -58.469813            -34.564122  861866BAEcobici
# 1             -58.368174            -34.611102  217525BAEcobici
# 2             -58.449379            -34.633528  954201BAEcobici
# 3             -58.477209            -34.616212  179414BAEcobici
# 4             -58.426387            -34.577424    8098BAEcobici
#
#   modelo_bicicleta  género fecha_origen_recorrido_dt  \
# 0           ICONIC    MALE       2023-04-24 10:30:10
# 1           ICONIC  FEMALE       2023-03-22 17:40:55
# 2           ICONIC    MALE       2023-02-15 23:12:22
# 3           ICONIC    MALE       2023-05-03 11:00:20
# 4           ICONIC    MALE       2023-02-06 06:50:58
#
#   fecha_destino_recorrido_dt
# 0        2023-04-24 11:00:58
# 1        2023-03-22 17:45:43
# 2        2023-02-15 23:30:45
# 3        2023-05-03 11:19:45
# 4        2023-02-06 06:57:16

# %%
bicis.dtypes
# Out:
# Unnamed: 0                             int64
# Id_recorrido                          object
# duracion_recorrido                    object
# fecha_origen_recorrido                object
# id_estacion_origen                    object
# nombre_estacion_origen                object
# direccion_estacion_origen             object
# long_estacion_origen                 float64
# lat_estacion_origen                  float64
# fecha_destino_recorrido               object
# id_estacion_destino                   object
# nombre_estacion_destino               object
# direccion_estacion_destino            object
# long_estacion_destino                float64
# lat_estacion_destino                 float64
# id_usuario                            object
# modelo_bicicleta                      object
# género                                object
# fecha_origen_recorrido_dt     datetime64[ns]
# fecha_destino_recorrido_dt    datetime64[ns]
# dtype: object

# %%
# Calculo la diferencia de tiempo y los llamo duracion_recorrido_dt
bicis['duracion_recorrido_dt'] = bicis['fecha_destino_recorrido_dt'] - bicis['fecha_origen_recorrido_dt']

# %%
bicis.head()
# Out:
#    Unnamed: 0       Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0           1  17910696BAEcobici              1,848    2023-04-24 10:30:10
# 1           2  17600256BAEcobici                288    2023-03-22 17:40:55
# 2           3  17255670BAEcobici              1,103    2023-02-15 23:12:22
# 3           4  17996972BAEcobici              1,165    2023-05-03 11:00:20
# 4           5  17148836BAEcobici                378    2023-02-06 06:50:58
#
#   id_estacion_origen        nombre_estacion_origen  \
# 0       358BAEcobici                  249 - Balbín
# 1       444BAEcobici  061 - Ministerio de Economia
# 2       280BAEcobici           222 - SIMON BOLIVAR
# 3       273BAEcobici                  223 - GAINZA
# 4        65BAEcobici          065 - Julián Álvarez
#
#            direccion_estacion_origen  long_estacion_origen  \
# 0                        2519 Conesa            -58.465586
# 1  Balcarce e Yrigoyen, Hipolito Av.            -58.370716
# 2   1701 Fernandez Moreno, Baldomero            -58.449379
# 3       494 Gainza, Martin De, Gral.            -58.446751
# 4                        3822 Guemes            -58.415787
#
#    lat_estacion_origen fecha_destino_recorrido  ... nombre_estacion_destino  \
# 0           -34.561486     2023-04-24 11:00:58  ...            233 - MONROE
# 1           -34.608936     2023-03-22 17:45:43  ...            003 - ADUANA
# 2           -34.633528     2023-02-15 23:30:45  ...     222 - SIMON BOLIVAR
# 3           -34.616758     2023-05-03 11:19:45  ...       287 - Belaustegui
# 4           -34.587312     2023-02-06 06:57:16  ...          014 - Pacifico
#
#           direccion_estacion_destino long_estacion_destino  \
# 0                        2519 Superi            -58.469813
# 1                  Moreno & Azopardo            -58.368174
# 2   1701 Fernandez Moreno, Baldomero            -58.449379
# 3        Belaustegui, Luis, Dr. 2890            -58.477209
# 4  Santa Fe Av. & Bullrich, Int. Av.            -58.426387
#
#    lat_estacion_destino       id_usuario modelo_bicicleta  género  \
# 0            -34.564122  861866BAEcobici           ICONIC    MALE
# 1            -34.611102  217525BAEcobici           ICONIC  FEMALE
# 2            -34.633528  954201BAEcobici           ICONIC    MALE
# 3            -34.616212  179414BAEcobici           ICONIC    MALE
# 4            -34.577424    8098BAEcobici           ICONIC    MALE
#
#   fecha_origen_recorrido_dt fecha_destino_recorrido_dt duracion_recorrido_dt
# 0       2023-04-24 10:30:10        2023-04-24 11:00:58       0 days 00:30:48
# 1       2023-03-22 17:40:55        2023-03-22 17:45:43       0 days 00:04:48
# 2       2023-02-15 23:12:22        2023-02-15 23:30:45       0 days 00:18:23
# 3       2023-05-03 11:00:20        2023-05-03 11:19:45       0 days 00:19:25
# 4       2023-02-06 06:50:58        2023-02-06 06:57:16       0 days 00:06:18
#
# [5 rows x 21 columns]

# %%
# El tipo de dato de la nueva columna no resulta conveniente:
bicis.dtypes
# Out:
# Unnamed: 0                              int64
# Id_recorrido                           object
# duracion_recorrido                     object
# fecha_origen_recorrido                 object
# id_estacion_origen                     object
# nombre_estacion_origen                 object
# direccion_estacion_origen              object
# long_estacion_origen                  float64
# lat_estacion_origen                   float64
# fecha_destino_recorrido                object
# id_estacion_destino                    object
# nombre_estacion_destino                object
# direccion_estacion_destino             object
# long_estacion_destino                 float64
# lat_estacion_destino                  float64
# id_usuario                             object
# modelo_bicicleta                       object
# género                                 object
# fecha_origen_recorrido_dt      datetime64[ns]
# fecha_destino_recorrido_dt     datetime64[ns]
# duracion_recorrido_dt         timedelta64[ns]
# dtype: object

# %%
# Por ende creo una nueva columna con los valores de minutos totales con formato float
bicis['duracion_recorrido_min'] = bicis['duracion_recorrido_dt'].dt.total_seconds() / 60

# %%
bicis.head()
# Out:
#    Unnamed: 0       Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0           1  17910696BAEcobici              1,848    2023-04-24 10:30:10
# 1           2  17600256BAEcobici                288    2023-03-22 17:40:55
# 2           3  17255670BAEcobici              1,103    2023-02-15 23:12:22
# 3           4  17996972BAEcobici              1,165    2023-05-03 11:00:20
# 4           5  17148836BAEcobici                378    2023-02-06 06:50:58
#
#   id_estacion_origen        nombre_estacion_origen  \
# 0       358BAEcobici                  249 - Balbín
# 1       444BAEcobici  061 - Ministerio de Economia
# 2       280BAEcobici           222 - SIMON BOLIVAR
# 3       273BAEcobici                  223 - GAINZA
# 4        65BAEcobici          065 - Julián Álvarez
#
#            direccion_estacion_origen  long_estacion_origen  \
# 0                        2519 Conesa            -58.465586
# 1  Balcarce e Yrigoyen, Hipolito Av.            -58.370716
# 2   1701 Fernandez Moreno, Baldomero            -58.449379
# 3       494 Gainza, Martin De, Gral.            -58.446751
# 4                        3822 Guemes            -58.415787
#
#    lat_estacion_origen fecha_destino_recorrido  ...  \
# 0           -34.561486     2023-04-24 11:00:58  ...
# 1           -34.608936     2023-03-22 17:45:43  ...
# 2           -34.633528     2023-02-15 23:30:45  ...
# 3           -34.616758     2023-05-03 11:19:45  ...
# 4           -34.587312     2023-02-06 06:57:16  ...
#
#           direccion_estacion_destino long_estacion_destino  \
# 0                        2519 Superi            -58.469813
# 1                  Moreno & Azopardo            -58.368174
# 2   1701 Fernandez Moreno, Baldomero            -58.449379
# 3        Belaustegui, Luis, Dr. 2890            -58.477209
# 4  Santa Fe Av. & Bullrich, Int. Av.            -58.426387
#
#   lat_estacion_destino       id_usuario  modelo_bicicleta  género  \
# 0           -34.564122  861866BAEcobici            ICONIC    MALE
# 1           -34.611102  217525BAEcobici            ICONIC  FEMALE
# 2           -34.633528  954201BAEcobici            ICONIC    MALE
# 3           -34.616212  179414BAEcobici            ICONIC    MALE
# 4           -34.577424    8098BAEcobici            ICONIC    MALE
#
#   fecha_origen_recorrido_dt fecha_destino_recorrido_dt duracion_recorrido_dt  \
# 0       2023-04-24 10:30:10        2023-04-24 11:00:58       0 days 00:30:48
# 1       2023-03-22 17:40:55        2023-03-22 17:45:43       0 days 00:04:48
# 2       2023-02-15 23:12:22        2023-02-15 23:30:45       0 days 00:18:23
# 3       2023-05-03 11:00:20        2023-05-03 11:19:45       0 days 00:19:25
# 4       2023-02-06 06:50:58        2023-02-06 06:57:16       0 days 00:06:18
#
#   duracion_recorrido_min
# 0              30.800000
# 1               4.800000
# 2              18.383333
# 3              19.416667
# 4               6.300000
#
# [5 rows x 22 columns]

# %%
# Veo cuantos registros tengo por cada valor de estacion origen
bicis['nombre_estacion_origen'].value_counts()
# Out:
# nombre_estacion_origen
# 147 - Constitución                 35834
# 014 - Pacifico                     31698
# 008 - Congreso                     27249
# 005 - Plaza Italia                 24924
# 001 - FACULTAD DE DERECHO          22779
#                                    ...
# 081 - PARQUE DE LA CIENCIA           273
# 212 - TRES ARROYOS                   109
# 180 - PARQUE OLIMPICO                104
# 389 - Plaza República De Mexico       16
# -CDO BARRACAS-                        10
# Name: count, Length: 365, dtype: int64

# %%
# Creo un nuevo dataframe con los registros de la estación Constitución
bicis_constitucion = bicis[bicis['nombre_estacion_origen'] == '147 - Constitución']

# %%
bicis_constitucion.head()
# Out:
#      Unnamed: 0       Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 35           36  18349462BAEcobici              1,029    2023-06-14 23:54:50
# 66           67  16944587BAEcobici              1,176    2023-01-16 19:11:15
# 131         132  17155654BAEcobici              2,749    2023-02-06 17:34:49
# 186         187  16870416BAEcobici              1,573    2023-01-09 12:56:14
# 198         199  16952968BAEcobici                715    2023-01-17 15:12:03
#
#     id_estacion_origen nombre_estacion_origen   direccion_estacion_origen  \
# 35        175BAEcobici     147 - Constitución  Avenida Juan de Garay 1050
# 66        175BAEcobici     147 - Constitución  Avenida Juan de Garay 1050
# 131       175BAEcobici     147 - Constitución  Avenida Juan de Garay 1050
# 186       175BAEcobici     147 - Constitución  Avenida Juan de Garay 1050
# 198       175BAEcobici     147 - Constitución  Avenida Juan de Garay 1050
#
#      long_estacion_origen  lat_estacion_origen fecha_destino_recorrido  ...  \
# 35             -58.380707           -34.626851     2023-06-15 00:11:59  ...
# 66             -58.380707           -34.626851     2023-01-16 19:30:51  ...
# 131            -58.380707           -34.626851     2023-02-06 18:20:38  ...
# 186            -58.380707           -34.626851     2023-01-09 13:22:27  ...
# 198            -58.380707           -34.626851     2023-01-17 15:23:58  ...
#
#         direccion_estacion_destino long_estacion_destino lat_estacion_destino  \
# 35                    1590 Lavalle            -58.389373           -34.603269
# 66    Reconquista & Corrientes Av.            -58.372763           -34.603369
# 131             Av. Rivadavia 6955            -58.463297           -34.628836
# 186  776 Reconquista & Cordoba Av.            -58.373062           -34.598600
# 198      2908 Salcedo & Dean Funes            -58.405339           -34.631644
#
#           id_usuario  modelo_bicicleta  género fecha_origen_recorrido_dt  \
# 35   468004BAEcobici            ICONIC    MALE       2023-06-14 23:54:50
# 66     1917BAEcobici            ICONIC  FEMALE       2023-01-16 19:11:15
# 131   29130BAEcobici            ICONIC  FEMALE       2023-02-06 17:34:49
# 186  794184BAEcobici            ICONIC    MALE       2023-01-09 12:56:14
# 198  686228BAEcobici            ICONIC    MALE       2023-01-17 15:12:03
#
#     fecha_destino_recorrido_dt duracion_recorrido_dt duracion_recorrido_min
# 35         2023-06-15 00:11:59       0 days 00:17:09              17.150000
# 66         2023-01-16 19:30:51       0 days 00:19:36              19.600000
# 131        2023-02-06 18:20:38       0 days 00:45:49              45.816667
# 186        2023-01-09 13:22:27       0 days 00:26:13              26.216667
# 198        2023-01-17 15:23:58       0 days 00:11:55              11.916667
#
# [5 rows x 22 columns]

# %%
bicis_constitucion.shape
# Out:
# (35834, 22)

# %%
# Con el histograma veo que tengo datos anómalos, mas alla de los 60 minutos.
bicis_constitucion.hist('duracion_recorrido_min', bins=200)
# Out:
# array([[<Axes: title={'center': 'duracion_recorrido_min'}>]], dtype=object)

# %%
# Creo un nuevo dataframe con los registros dentro de la hora
bicis_constitucion_hora = bicis_constitucion[bicis_constitucion['duracion_recorrido_min'] < 60]

# %%
bicis_constitucion_hora.shape
# Out:
# (34980, 22)

# %%
# El histograma muestra una mejor distribución
bicis_constitucion_hora.hist('duracion_recorrido_min', bins=200, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'duracion_recorrido_min'}>]], dtype=object)

# %%
# El boxplot es otro gráfico que me brinda información sobre los datos.
bicis_constitucion_hora['duracion_recorrido_min'].plot(kind='box')
plt.show()

# %%
# El método describe() me brinda los estadísticos principales de una columna
bicis_constitucion_hora['duracion_recorrido_min'].describe()
# Out:
# count    34980.000000
# mean        17.108951
# std          9.668842
# min          1.016667
# 25%         10.466667
# 50%         15.033333
# 75%         21.316667
# max         59.983333
# Name: duracion_recorrido_min, dtype: float64

# %% [markdown]
# # 5. Cálculo de FDPS

# %%
# En una variable preparar la columna del df que quiero ajustar
fdp_constitucion_hora = Fitter(bicis_constitucion_hora.duracion_recorrido_min)

# %%
# Con el método fit() ajusta mis datos a las 80 distribuciones de SciPy
fdp_constitucion_hora.fit()

# %%
# Summary me muestra el resumen de los mejores ajustes
fdp_constitucion_hora.summary(10)
# Out:
#               sumsquare_error          aic          bic    kl_div  \
# f                    0.001025  1009.796319  1043.646446  0.022191
# betaprime            0.001026  1008.765762  1042.615889  0.020540
# lognorm              0.001030  1007.566744  1032.954339  0.021626
# exponweib            0.001034  1009.639570  1043.489697  0.021028
# johnsonsb            0.001036  1009.564152  1043.414279  0.022030
# powerlognorm         0.001036  1008.365920  1042.216047  0.020446
# invgamma             0.001042  1005.862957  1031.250552  0.019954
# burr12               0.001068  1008.754567  1042.604694  0.024348
# invgauss             0.001070  1008.546702  1033.934297  0.023054
# johnsonsu            0.001084  1006.591600  1040.441727  0.018890
#
#               ks_statistic     ks_pvalue
# f                 0.013190  1.026295e-05
# betaprime         0.013220  9.696274e-06
# lognorm           0.012790  2.124282e-05
# exponweib         0.012259  5.388053e-05
# johnsonsb         0.013467  6.119694e-06
# powerlognorm      0.012294  5.068862e-05
# invgamma          0.014697  5.416905e-07
# burr12            0.016252  1.866609e-08
# invgauss          0.017474  1.043412e-09
# johnsonsu         0.015411  1.202149e-07

# %% [markdown]
# # 6. Simulacion

# %%
# get_best me devuelve la mejor distribución de acuerdo al criterio que le indico y sus parámetros
fdp_constitucion_hora.get_best(method='sumsquare_error')
# Out:
# {'f': {'dfn': 10.210149046195188,
#   'dfd': 24.449261873976212,
#   'loc': -0.210629715477468,
#   'scale': 15.900756775955681}}

# %%
fdp_constitucion_hora.get_best(method='ks_statistic')
# Out:
# {'exponweib': {'a': 16.01375378484699,
#   'c': 0.7896251990908474,
#   'loc': -2.857372846433768,
#   'scale': 4.163804898935379}}

# %%
# Para simular, guardo los valores de los parámetros en 4 variables
dfn = 10.210149046195188
dfd = 24.449261873976212
loc = -0.210629715477468
scale =  15.900756775955681

# %%
# Gracias al método rvs del módulo stats de Scipy, puedo generar datos
# con los parámetros que me dio Fitter
fdp_f = stats.f.rvs(dfn, dfd, loc=loc, scale=scale, size=35000)

# %%
# Esta variable es un array de Numpy con valores similares a mis datos de origen
fdp_f
# Out:
# array([14.7250755 ,  9.20535589,  6.21281223, ..., 12.15758994,
#        14.66241261, 12.29791879])

# %%
# Histograma de datos de verificación
plt.title("Histograma")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.xlim(0, 60)
plt.ylim(0, 1300)
plt.hist(fdp_f, bins=150)
plt.show()
